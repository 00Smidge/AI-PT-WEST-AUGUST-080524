# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]
temp_c = []
for i in temp:
    temp_c.append((i - 32) * 0.56)

# %%
# Tell matplotlib to create a scatter plot based upon the above data
# Without scoop_price
# plt.scatter(temp, sales, marker='o', facecolors='#42b883', edgecolors='#843b30')


scoop_price = [89, 18, 10, 28, 79, 46, 29, 38, 89, 26, 45, 62]
# BONUS: With scoop_price set to the scalar value
plt.scatter(
    temp, sales, s=scoop_price, marker="o", facecolors="#ff3d00", edgecolors="#843b30"
)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/09-figure-step-1.png)
# -->

# %%
# Set the upper and lower limits of our y axis

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/09-figure-step-2.png)
# -->

# %%
# Set the upper and lower limits of our x axis

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/09-figure-step-3.png)
# -->

# %%
# Create a title, x label, and y label for our chart

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/09-figure-step-4.png)
# -->

# %%
# Save an image of the chart and print to screen

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/09-figure-step-4.png)
# -->
